# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # 2. Data Loading

# %%
df = pd.read_csv(r"C:\Users\Mahmoud Ashraf\ieee-jupyter\task12\netflix1.csv")

# %% [markdown]
# # 3. Exploring Data

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.head(10)
# Out:
#   show_id     type                             title             director  \
# 0      s1    Movie              Dick Johnson Is Dead      Kirsten Johnson
# 1      s3  TV Show                         Ganglands      Julien Leclercq
# 2      s6  TV Show                     Midnight Mass        Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl        Bruno Garotti
# 4      s8    Movie                           Sankofa         Haile Gerima
# 5      s9  TV Show     The Great British Baking Show      Andy Devonshire
# 6     s10    Movie                      The Starling       Theodore Melfi
# 7    s939    Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8     s13    Movie                      Je Suis Karl  Christian Schwochow
# 9    s940    Movie          Motu Patlu in Wonderland          Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# ...

# %%
df.tail(10)
# Out:
#      show_id     type                   title   director         country  \
# 8780   s8759  TV Show  World's Busiest Cities  Not Given  United Kingdom
# 8781   s8776  TV Show         Yeh Meri Family  Not Given           India
# 8782   s8781  TV Show            Yo-Kai Watch  Not Given   United States
# 8783   s8785    Movie    Yoko and His Friends  Not Given          Russia
# 8784   s8796  TV Show         Yu-Gi-Oh! Arc-V  Not Given           Japan
# 8785   s8797  TV Show              Yunus Emre  Not Given          Turkey
# 8786   s8798  TV Show               Zak Storm  Not Given   United States
# 8787   s8801  TV Show      Zindagi Gulzar Hai  Not Given        Pakistan
# 8788   s8784  TV Show                    Yoko  Not Given        Pakistan
# 8789   s8786  TV Show                     YOM  Not Given        Pakistan
#
#       date_added  release_year rating   duration  \
# 8780    2/1/2019          2017  TV-PG   1 Season
# 8781   8/31/2018          2018  TV-PG   1 Season
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %% [markdown]
# # 4. Data Cleaning

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# # Total Content on Netflix

# %%
df.show_id.count()
# Out:
# 8790

# %% [markdown]
# #  Top 10 countries with Netflix Content

# %%
df.groupby("country").show_id.count().sort_values(ascending=False).head(10)
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: show_id, dtype: int64

# %% [markdown]
# # Monthly Trend of Movie and TV Show Releases

# %%
df['date_added']=pd.to_datetime(df['date_added'])
df['month'] = df['date_added'].dt.month
df.groupby('month').release_year.count()
# Out:
# month
# 1     737
# 2     562
# 3     741
# 4     763
# 5     632
# 6     728
# 7     827
# 8     754
# 9     769
# 10    760
# 11    705
# 12    812
# Name: release_year, dtype: int64

# %% [markdown]
# #  Yearly Trend of Movie and TV Show Releases

# %%
df['year'] = df['date_added'].dt.year
df.groupby('year').release_year.count()
# Out:
# year
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      11
# 2014      24
# 2015      82
# 2016     426
# 2017    1185
# 2018    1648
# 2019    2016
# 2020    1879
# 2021    1498
# Name: release_year, dtype: int64

# %% [markdown]
# # Top 10 Movies

# %%
filter = df['type'] == 'Movie'
df[filter].sort_values(by='release_year', ascending=False).head(10)
# Out:
#      show_id   type                                   title  \
# 949     s906  Movie                                Super Me
# 1259   s1346  Movie  The Yin-Yang Master: Dream Of Eternity
# 1243   s1326  Movie                                 Red Dot
# 1244   s1327  Movie                            Squared Love
# 1248   s1330  Movie   The Misadventures of Hedi and Cokeman
# 1255   s1342  Movie                         Malcolm & Marie
# 692     s501  Movie               Major Grom: Plague Doctor
# 1256   s1343  Movie                          Space Sweepers
# 1257   s1344  Movie                     Strip Down, Rise Up
# 688     s472  Movie                          Day of Destiny
#
#                     director        country date_added  release_year rating  \
# 949              Zhang Chong          China 2021-05-08          2021  TV-14
# 1259            Guo Jingming          China 2021-02-05          2021  TV-14
# ...

# %% [markdown]
# # Top 10 TV Show

# %%
filter = df['type'] == 'TV Show'
df[filter].sort_values(by='release_year', ascending=False).head(10)
# Out:
#      show_id     type                             title         director  \
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 6840   s1207  TV Show                        Zero Chill        Not Given
# 6843   s1214  TV Show                       Paradise PD        Not Given
# 6844   s1218  TV Show                           The One        Not Given
# 6845   s1227  TV Show                     The Houseboat        Not Given
# 6846   s1228  TV Show                     Bombay Begums        Not Given
# 6848   s1232  TV Show                    City of Ghosts        Not Given
# 6849   s1239  TV Show            Pacific Rim: The Black        Not Given
# 6850   s1246  TV Show                        Word Party        Not Given
# 6855   s1273  TV Show  Age of Samurai: Battle for Japan        Not Given
#
#              country date_added  release_year rating   duration  \
# 1             France 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# #  Top_10_Directors

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Not Given                 2588
# Rajiv Chilaka               20
# Alastair Fothergill         18
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Name: count, dtype: int64
